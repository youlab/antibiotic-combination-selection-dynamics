# %% [markdown]
# Define the growth function which takes in the current state of the system y, the parameters p, and the presence or absence of inhibitors inh as arguments. This function describes the rates of change of nutrients n, the degrading enzyme b, and antibiotic a levels over time t under specific conditions.
#
# The simulate function is used to solve the defined ODEs for a given initial condition n0 and a0 over a certain time span using the solve_ivp function from the SciPy library. This function returns the simulated levels of nutrients, the degrading enzyme, and antibiotic over time.
#
# The objective function computes the sum of squared differences between the simulated nutrient levels and the observed experimental nutrient levels for all time points and initial conditions. This function is typically used in parameter estimation where the goal is to find the parameters p that minimize the difference between the simulated and experimental results.
#
# Here, the growth function is defined to be flexible enough to capture the general trend of experimental growth curves. Many of these exhibit approximately 2-stage growth. A simple logistic model or Monod equation does not capture the growth curve well. The term 'g' is re-defined to approximate this behavior (to some extent). There might be better alternatives.

# %% [markdown]
# In the following code, the initial parameter values are from the NN estimated. Let's see if Sciy optimize can generate better fits for some or all isolates.

# %%
import numpy as np
from scipy.integrate import odeint, solve_ivp
from scipy.optimize import minimize

# %run ../simulation/growth_complete.ipynb   #defines growth dynamics and simulation method

# %%
#
# 1st round of parameter estimation.
#
# Bounds for the parameter values
# alpha, Ks, theta, Ln, kappab, phimax, gamma, betamin, db, c
parameter_names = ['alpha','Ks','theta', 'Ln', 'kappab', 'phimax', 'gamma', 'betamin', 'db', 'c']

#old_estimate = np.load("../estimated/v7_NN_round1.npy")
#old_estimate = np.mean(old_estimate, axis = 1)

estimated_gr= np.load('../estimated/gravg2.npy')  #estimated alpha, Ks, and theta. will be fixed in subsequent optimization.

# print(old_estimate.shape)
# p0 = np.array([(lower + upper) / 2 for lower, upper in parameter_bounds])

# load the experimental data
experimental_all = np.load('../isolates/avg_OD_all_isolates.npy')
strain_ids = np.load('../isolates/strain_ids.npy', allow_pickle=True)

print("experimental_all shape:", experimental_all.shape)

num_parameter_sets = 311 # Run the optimization for each strain, using averaged growth curves.
num_runs = 10

for k in range(num_runs):
    optimal_parameters = []
    initial_guesses = []
    for i in range(num_parameter_sets):
        experimental = experimental_all[i]
        
        # Define the constraint function for parameter bounds, which are required by other optimization methods.
        #constraint = {'type': 'ineq', 'fun': lambda p: np.array([p[j] - parameter_bounds[j][0] for j in range(len(p))])}
        
        #p0 = old_estimate[i]
        p0 = np.zeros(10)
        p0[0:3] = estimated_gr[i, 0:3]

        #set the bounds such that the first 3 parameters will not change during optimization.
        parameter_bounds = [(p0[0], p0[0]), (p0[1], p0[1]), (p0[2], p0[2]), 
                            (0, 0.8), (0, 6), (0, 6),
                            (0.0, 6), (0, 1), (0, 6), (0, 1)]

        #set the means and standard deviations of the normal distribution
        parameter_means = [p0[0], p0[1], p0[2], 0.4, 3, 3, 1.35, 0.5, 3, 0.146]
        parameter_sds = [0, 0, 0, 0.4/3, 1, 1, 0.55/3, 0.5/3, 1, 0.0487]

        for j in range(3, 10):
            p0[j] = np.random.normal(parameter_means[j], parameter_sds[j])
        #print(p0)  
        initial_guesses.append(p0)
        
        result = minimize(objective, p0, args=(experimental,), method='Nelder-Mead', tol = 1e-7, bounds=parameter_bounds)
        optimal_parameters.append(result.x)
        interval = 1 if i<10 else 10
        if ((i+1) % interval == 0):
            print(strain_ids[i])
    #        for p in optimal_parameters[i]:
            for j in range(len(optimal_parameters[i])):
                name = parameter_names[j]
                p = optimal_parameters[i][j]
                print(name, f"={p:.2f}", end="; ")
            print()  # Print a new line after each simulation

    # Convert the list of optimized parameters to a numpy array
    initial_guess_array = np.array(initial_guesses)
    optimal_parameters_array = np.array(optimal_parameters)
    # Save the optimized parameters to a .npy file
    np.save(('../estimated/scipy_all_para_v14_' + str(k)), optimal_parameters_array)
    np.save(('../estimated/scipy_initials_v14_' + str(k)), initial_guess_array)
# Out:
# experimental_all shape: (311, 3, 145)
# 2004
# alpha =0.87; Ks =0.11; theta =1.83; Ln =0.06; kappab =0.06; phimax =0.02; gamma =2.68; betamin =0.30; db =6.00; c =0.00;
# 2005
# alpha =1.03; Ks =0.15; theta =2.21; Ln =0.07; kappab =0.00; phimax =0.00; gamma =1.03; betamin =0.98; db =4.35; c =0.69;
# 2007
# alpha =0.88; Ks =0.17; theta =2.63; Ln =0.43; kappab =5.95; phimax =2.55; gamma =1.32; betamin =0.77; db =6.00; c =0.15;
# 2009
# alpha =0.84; Ks =0.19; theta =3.64; Ln =0.26; kappab =0.00; phimax =3.54; gamma =0.88; betamin =0.00; db =5.69; c =1.00;
# 2039
# alpha =0.84; Ks =0.19; theta =3.38; Ln =0.18; kappab =0.09; phimax =1.71; gamma =1.66; betamin =0.49; db =2.39; c =0.05;
# 2045
# alpha =0.85; Ks =0.20; theta =3.85; Ln =0.54; kappab =4.01; phimax =3.54; gamma =2.11; betamin =0.55; db =5.34; c =0.05;
# 2050
# alpha =0.78; Ks =0.18; theta =3.35; Ln =0.39; kappab =3.41; phimax =3.73; gamma =4.33; betamin =0.00; db =1.11; c =0.25;
# /tmp/ipykernel_2866791/751365360.py:52: OptimizeWarning: Initial guess is not within the specified bounds
#   result = minimize(objective, p0, args=(experimental,), method='Nelder-Mead', tol = 1e-7, bounds=parameter_bounds)
# 2055
# alpha =0.91; Ks =0.19; theta =3.03; Ln =0.32; kappab =6.00; phimax =6.00; gamma =1.00; betamin =0.00; db =6.00; c =1.00;
# 2060
# alpha =1.23; Ks =0.10; theta =1.71; Ln =0.15; kappab =0.11; phimax =0.06; gamma =1.19; betamin =0.99; db =6.00; c =0.08;
# 2091
# alpha =0.88; Ks =0.19; theta =3.40; Ln =0.35; kappab =6.00; phimax =0.00; gamma =2.91; betamin =0.00; db =6.00; c =0.30;
# 2175
# alpha =0.79; Ks =0.17; theta =3.25; Ln =0.30; kappab =0.00; phimax =5.86; gamma =0.95; betamin =0.00; db =0.00; c =0.88;
# 2289
# alpha =0.84; Ks =0.19; theta =3.58; Ln =0.38; kappab =5.09; phimax =0.00; gamma =2.56; betamin =0.00; db =5.63; c =0.33;
# 2345
# alpha =0.69; Ks =0.20; theta =4.24; Ln =0.15; kappab =0.08; phimax =1.47; gamma =0.69; betamin =1.00; db =1.20; c =0.54;
# 2405
# alpha =0.64; Ks =0.20; theta =4.62; Ln =0.21; kappab =1.45; phimax =2.63; gamma =2.28; betamin =0.43; db =2.92; c =0.24;
# 2449
# alpha =0.95; Ks =0.13; theta =2.03; Ln =0.31; kappab =0.70; phimax =0.00; gamma =2.64; betamin =0.46; db =5.20; c =0.16;
# 2514
# alpha =0.75; Ks =0.22; theta =4.67; Ln =0.27; kappab =0.00; phimax =5.96; gamma =6.00; betamin =0.00; db =5.42; c =0.16;
# 2590
# alpha =1.00; Ks =0.14; theta =2.37; Ln =0.38; kappab =5.96; phimax =0.00; gamma =3.16; betamin =0.00; db =6.00; c =0.35;
# 2631
# alpha =0.82; Ks =0.19; theta =3.34; Ln =0.40; kappab =5.89; phimax =0.33; gamma =3.61; betamin =0.00; db =2.75; c =0.24;
# 2699
# alpha =0.81; Ks =0.18; theta =3.51; Ln =0.31; kappab =0.00; phimax =3.32; gamma =2.12; betamin =0.00; db =2.75; c =0.40;
# 2779
# alpha =0.88; Ks =0.16; theta =2.88; Ln =0.51; kappab =5.65; phimax =2.88; gamma =1.62; betamin =0.49; db =4.47; c =0.36;
# 3148
# alpha =0.85; Ks =0.20; theta =3.68; Ln =0.60; kappab =6.00; phimax =0.00; gamma =5.75; betamin =0.00; db =6.00; c =0.15;
# 3415
# alpha =0.81; Ks =0.16; theta =3.16; Ln =0.35; kappab =0.14; phimax =2.68; gamma =3.46; betamin =0.28; db =0.00; c =0.00;
# 3786
# alpha =0.96; Ks =0.14; theta =2.33; Ln =0

# 2039
# alpha =0.84; Ks =0.19; theta =3.38; Ln =0.24; kappab =4.38; phimax =4.92; gamma =2.99; betamin =0.80; db =0.00; c =0.05;
# 2045
# alpha =0.85; Ks =0.20; theta =3.85; Ln =0.20; kappab =5.64; phimax =4.23; gamma =2.72; betamin =0.00; db =1.77; c =0.36;
# 2050
# alpha =0.78; Ks =0.18; theta =3.35; Ln =0.47; kappab =5.97; phimax =4.95; gamma =2.30; betamin =0.53; db =5.93; c =0.03;
# 2055
# alpha =0.91; Ks =0.19; theta =3.03; Ln =0.40; kappab =5.98; phimax =0.20; gamma =2.26; betamin =0.35; db =1.94; c =0.16;
# 2060
# alpha =1.23; Ks =0.10; theta =1.71; Ln =0.15; kappab =0.02; phimax =0.21; gamma =1.20; betamin =0.98; db =6.00; c =0.20;
# 2091
# alpha =0.88; Ks =0.19; theta =3.40; Ln =0.42; kappab =0.00; phimax =0.44; gamma =2.60; betamin =0.00; db =5.98; c =0.34;
# 2175
# alpha =0.79; Ks =0.17; theta =3.25; Ln =0.26; kappab =0.00; phimax =1.67; gamma =2.33; betamin =0.00; db =0.00; c =0.36;
# 2289
# alpha =0.84; Ks =0.19; theta =3.58; Ln =0.45; kappab =0.00; phimax =0.01; gamma =3.26; betamin =0.00; db =5.23; c =0.26;
# 2345
# alpha =0.69; Ks =0.20; theta =4.24; Ln =0.09; kappab =0.00; phimax =1.90; gamma =0.79; betamin =0.81; db =6.00; c =0.29;
# 2405
# alpha =0.64; Ks =0.20; theta =4.62; Ln =0.22; kappab =0.00; phimax =2.66; gamma =1.78; betamin =0.39; db =1.78; c =0.00;
# 2449
# alpha =0.95; Ks =0.13; theta =2.03; Ln =0.19; kappab =0.01; phimax =5.05; gamma =3.55; betamin =0.29; db =1.69; c =0.00;
# 2514
# alpha =0.75; Ks =0.22; theta =4.67; Ln =0.38; kappab =5.83; phimax =4.65; gamma =1.49; betamin =0.53; db =2.51; c =0.30;
# 2590
# alpha =1.00; Ks =0.14; theta =2.37; Ln =0.33; kappab =1.10; phimax =0.00; gamma =1.55; betamin =0.00; db =6.00; c =0.70;
# 2631
# alpha =0.82; Ks =0.19; theta =3.34; Ln =0.48; kappab =5.92; phimax =1.22; gamma =6.00; betamin =0.00; db =6.00; c =0.15;
# 2699
# alpha =0.81; Ks =0.18; theta =3.51; Ln =0.37; kappab =4.41; phimax =2.25; gamma =1.44; betamin =0.60; db =2.50; c =0.14;
# 2779
# alpha =0.88; Ks =0.16; theta =2.88; Ln =0.27; kappab =2.89; phimax =0.88; gamma =5.38; betamin =0.00; db =1.25; c =0.17;
# 3148
# alpha =0.85; Ks =0.20; theta =3.68; Ln =0.27; kappab =0.29; phimax =0.00; gamma =1.18; betamin =0.00; db =4.00; c =0.66;
# 3415
# alpha =0.81; Ks =0.16; theta =3.16; Ln =0.13; kappab =0.00; phimax =2.67; gamma =0.83; betamin =1.00; db =5.89; c =0.00;
# 3786
# alpha =0.96; Ks =0.14; theta =2.33; Ln =0.61; kappab =0.45; phimax =6.00; gamma =1.24; betamin =0.28; db =5.99; c =0.86;
# 4124
# alpha =0.82; Ks =0.17; theta =2.88; Ln =0.45; kappab =5.00; phimax =0.87; gamma =2.64; betamin =0.00; db =3.19; c =0.34;
# 4318
# alpha =0.74; Ks =0.20; theta =3.74; Ln =0.80; kappab =6.00; phimax =4.27; gamma =4.40; betamin =0.00; db =5.99; c =0.40;
# 4665
# alpha =0.75; Ks =0.19; theta =3.43; Ln =0.45; kappab =0.03; phimax =0.00; gamma =2.73; betamin =0.00; db =6.00; c =0.29;
# 5107
# alpha =0.80; Ks =0.18; theta =3.31; Ln =0.39; kappab =0.00; phimax =0.93; gamma =1.65; betamin =0.00; db =6.00; c =0.54;
# 5509
# alpha =0.76; Ks =0.20; theta =3.65; Ln =0.33; kappab =6.00; phimax =2.93; gamma =2.95; betamin =0.00; db =5.71; c =0.29;
# 5826
# alpha =0.78; Ks =0.19; theta =3.40; Ln =0.20; kappab =4.21; phimax =1.49; gamma =2.85; betamin =0.00; db =0.98; c =0.30;
# 6039
# alpha =0.85; Ks =0.16; theta =2.53; Ln =0.24; kappab =3.35; phimax =0.18; gamma =2.74; betamin =0.02; db =5.24; c =0.32;
# 1026002900
# alpha =0.82; Ks =0.12; theta =3.69; Ln =0.21; kappab =6.00; phimax =0.00; gamma =2.71; betamin =0.00; db =6.00; c =0.35;
# MD0040
# alpha =1.00; Ks =0.11; theta =2.11; Ln =0.37; kappab =6.00; phimax =1.54; gamma =3.06; betamin =0.00; db =1.68; c =0.39;
# DICON003
# alpha =0.82; Ks =0.17; theta =3.08; Ln =0.36; kappab =6.00; phimax =2.16; gamma =3.01; betamin =0.00; db =1.89; c =0.33;
# DICON026
# alpha =2.23; Ks =0.04; theta =1.47; Ln =0.45; kappab =0.00; phimax =0.00; gamma =4.70; betamin =0.00; db =0.16; c =0.49;
# DICON044
# alpha =0.85; Ks =0.20; theta =3.37; Ln =0.25; kappab =3.44; phimax =0.01; gamma =1.27; betamin =0.00; db =5.72; c =0.64;
# DICON060
# alpha =0.87; Ks =0.18; theta =3.19; Ln =0.42; kappab =0.62; phimax =2.36; gamma =5.99; betamin =0.00; db =5.98; c =0.22;
# DICON098
# alpha =1.23; Ks =0.14; theta =2.57; Ln =0.49; kappab =5.64; phimax =2.11; gamma =1.26; betamin =0.16; db =6.00; c =1.00;
# DICON126
# alpha =1.22; Ks =0.07; theta =1.46; Ln =0.63; kappab =3.58; phimax =1.13; gamma =2.00; betamin =0.62; db =3.47; c =0.15;
# DICON174
# alpha =0.93; Ks =0.18; theta =2.84; Ln =0.56; kappab =3.42; phimax =0.15; gamma =3.80; betamin =0.00; db =0.61; c =0.19;
# DICON210
# alpha =1.04; Ks =0.14; theta =2.30; Ln =0.46; kappab =5.63; phimax =0.77; gamma =2.73; betamin =0.31; db =5.98; c =0.11;
# 2004
# alpha =0.87; Ks =0.11; theta =1.83; Ln =0.25; kappab =0.27; phimax =1.11; gamma =1.32; betamin =0.70; db =4.44; c =0.74;
# 2005
# alpha =1.03; Ks =0.15; theta =2.21; Ln =0.09; kappab =0.00; phimax =4.27; gamma =2.29; betamin =0.45; db =3.49; c =0.01;
# 2007
# alpha =0.88; Ks =0.17; theta =2.63; Ln =0.35; kappab =6.00; phimax =2.60; gamma =2.75; betamin =0.00; db =2.12; c =0.38;
# 2009
# alpha =0.84; Ks =0.19; theta =3.64; Ln =0.42; kappab =3.38; phimax =2.02; gamma =1.67; betamin =0.00; db =2.13; c =0.56;
# 2039
# alpha =0.84; Ks =0.19; theta =3.38; Ln =0.13; kappab =0.00; phimax =1.43; gamma =1.56; betamin =0.48; db =2.89; c =0.16;
# 2045
# alpha =0.85; Ks =0.20; theta =3.85; Ln =0.48; kappab =2.39; phimax =3.19; gamma =2.39; betamin =0.14; db =4.75; c =0.33;
# 2050
# alpha =0.78; Ks =0.18; theta =3.35; Ln =0.29; kappab =1.06; phimax =4.70; gamma =5.01; betamin =0.00; db =4.24; c =0.18;
# 2055
# alpha =0.91; Ks =0.19; theta =3.03; Ln =0.34; kappab =0.06; phimax =0.00; gamma =1.79; betamin =0.00; db =5.45; c =0.57;
# 2060
# alpha =1.23; Ks =0.10; theta =1.71; Ln =0.00; kappab =0.00; phimax =0.00; gamma =4.68; betamin =0.24; db =1.78; c =0.00;
# 2091
# alpha =0.88; Ks =0.19; theta =3.40; Ln =0.24; kappab =0.00; phimax =0.02; gamma =3.00; betamin =0.00; db =6.00; c =0.28;
# 2175
# alpha =0.79; Ks =0.17; theta =3.25; Ln =0.31; kappab =6.00; phimax =1.42; gamma =3.30; betamin =0.00; db =4.43; c =0.26;
# 2289
# alpha =0.84; Ks =0.19; theta =3.58; Ln =0.38; kappab =6.00; phimax =3.46; gamma =0.97; betamin =1.00; db =5.96; c =0.27;
# 2345
# alpha =0.69; Ks =0.20; theta =4.24; Ln =0.06; kappab =0.00; phimax =3.95; gamma =0.99; betamin =0.64; db =0.86; c =0.10;
# 2405
# alpha =0.64; Ks =0.20; theta =4.62; Ln =0.12; kappab =0.15; phimax =3.05; gamma =0.68; betamin =0.96; db =0.00; c =0.21;
# 2449
# alpha =0.95; Ks =0.13; theta =2.03; Ln =0.33; kappab =0.00; phimax =2.51; gamma =1.05; betamin =1.00; db =0.00; c =0.50;
# 2514
# alpha =0.75; Ks =0.22; theta =4.67; Ln =0.22; kappab =3.39; phimax =0.00; gamma =3.31; betamin =0.00; db =5.92; c =0.27;
# 2590
# alpha =1.00; Ks =0.14; theta =2.37; Ln =0.31; kappab =0.00; phimax =0.00; gamma =3.75; betamin =0.00; db =6.00; c =0.29;
# 2631
# alpha =0.82; Ks =0.19; theta =3.34; Ln =0.31; kappab =6.00; phimax =2.62; gamma =1.63; betamin =0.50; db =5.98; c =0.11;
# 2699
# alpha =0.81; Ks =0.18; theta =3.51; Ln =0.26; kappab =2.71; phimax =2.59; gamma =1.66; betamin =0.00; db =4.39; c =0.51;
# 2779
# alpha =0.88; Ks =0.16; theta =2.88; Ln =0.44; kappab =3.86; phimax =4.73; gamma =2.70; betamin =0.01; db =5.63; c =0.40;
# 3148
# alpha =0.85; Ks =0.20; theta =3.68; Ln =0.52; kappab =1.64; phimax =0.05; gamma =1.04; betamin =0.00; db =5.00; c =0.82;
# 3415
# alpha =0.81; Ks =0.16; theta =3.16; Ln =0.27; kappab =0.00; phimax =0.00; gamma =0.91; betamin =1.00; db =5.10; c =0.03;
# 3786
# alpha =0.96; Ks =0.14; theta =2.33; Ln =0.65; kappab =4.88; phimax =1.46; gamma =1.13; betamin =0.00; db =5.76; c =1.00;
# 4124
# alpha =0.82; Ks =0.17; theta =2.88; Ln =0.25; kappab =6.00; phimax =5.41; gamma =1.60; betamin =0.00; db =5.98; c =0.55;
# 4318
# alpha =0.74; Ks =0.20; theta =3.74; Ln =0.40; kappab =1.44; phimax =3.86; gamma =1.48; betamin =0.00; db =5.98; c =0.55;
# 4665
# alpha =0.75; Ks =0.19; theta =3.43; Ln =0.48; kappab =0.00; phimax =0.00; gamma =5.62; betamin =0.00; db =0.81; c =0.14;
# 5107
# alpha =0.80; Ks =0.18; theta =3.31; Ln =0.47; kappab =0.00; phimax =3.51; gamma =0.92; betamin =0.00; db =6.00; c =1.00;
# 5509
# alpha =0.76; Ks =0.20; theta =3.65; Ln =0.16; kappab =0.00; phimax =2.11; gamma =3.19; betamin =0.00; db =5.84; c =0.24;
# 5826
# alpha =0.78; Ks =0.19; theta =3.40; Ln =0.15; kappab =2.16; phimax =5.73; gamma =2.71; betamin =0.12; db =0.85; c =0.23;
# 6039
# alpha =0.85; Ks =0.16; theta =2.53; Ln =0.36; kappab =6.00; phimax =6.00; gamma =2.16; betamin =0.03; db =6.00; c =0.46;
# 1026002900
# alpha =0.82; Ks =0.12; theta =3.69; Ln =0.44; kappab =0.00; phimax =0.00; gamma =1.60; betamin =0.00; db =0.00; c =0.96;
# MD0040
# alpha =1.00; Ks =0.11; theta =2.11; Ln =0.27; kappab =3.72; phimax =2.00; gamma =1.83; betamin =0.00; db =1.19; c =0.60;
# DICON003
# alpha =0.82; Ks =0.17; theta =3.08; Ln =0.27; kappab =6.00; phimax =2.63; gamma =2.03; betamin =0.00; db =2.15; c =0.45;
# DICON026
# alpha =2.23; Ks =0.04; theta =1.47; Ln =0.66; kappab =5.93; phimax =1.67; gamma =5.29; betamin =0.00; db =5.62; c =0.52;
# DICON044
# alpha =0.85; Ks =0.20; theta =3.37; Ln =0.23; kappab =1.84; phimax =0.00; gamma =2.63; betamin =0.00; db =3.39; c =0.31;
# DICON060
# alpha =0.87; Ks =0.18; theta =3.19; Ln =0.26; kappab =6.00; phimax =3.70; gamma =3.50; betamin =0.00; db =5.95; c =0.29;
# DICON098
# alpha =1.23; Ks =0.14; theta =2.57; Ln =0.63; kappab =6.00; phimax =0.88; gamma =1.87; betamin =0.55; db =5.72; c =0.37;
# DICON126
# alpha =1.22; Ks =0.07; theta =1.46; Ln =0.42; kappab =0.00; phimax =0.00; gamma =4.62; betamin =0.00; db =2.56; c =0.26;
# DICON174
# alpha =0.93; Ks =0.18; theta =2.84; Ln =0.45; kappab =4.01; phimax =0.39; gamma =5.93; betamin =0.00; db =1.33; c =0.12;
# DICON210
# alpha =1.04; Ks =0.14; theta =2.30; Ln =0.40; kappab =0.00; phimax =0.00; gamma =3.34; betamin =0.00; db =5.96; c =0.30;
# 2004
# alpha =0.87; Ks =0.11; theta =1.83; Ln =0.21; kappab =0.00; phimax =2.91; gamma =2.70; betamin =0.34; db =4.70; c =0.00;
# 2005
# alpha =1.03; Ks =0.15; theta =2.21; Ln =0.14; kappab =0.00; phimax =4.63; gamma =2.61; betamin =0.41; db =5.56; c =0.01;
# 2007
# alpha =0.88; Ks =0.17; theta =2.63; Ln =0.34; kappab =5.49; phimax =4.79; gamma =2.81; betamin =0.00; db =6.00; c =0.37;
# 2009
# alpha =0.84; Ks =0.19; theta =3.64; Ln =0.31; kappab =5.76; phimax =1.76; gamma =2.53; betamin =0.04; db =1.00; c =0.38;
# 2039
# alpha =0.84; Ks =0.19; theta =3.38; Ln =0.09; kappab =0.00; phimax =0.61; gamma =1.33; betamin =0.55; db =1.38; c =0.39;
# 2045
# alpha =0.85; Ks =0.20; theta =3.85; Ln =0.15; kappab =6.00; phimax =0.00; gamma =1.01; betamin =0.00; db =1.86; c =0.90;
# 2050
# alpha =0.78; Ks =0.18; theta =3.35; Ln =0.22; kappab =5.55; phimax =4.32; gamma =3.38; betamin =0.00; db =6.00; c =0.26;
# 2055
# alpha =0.91; Ks =0.19; theta =3.03; Ln =0.40; kappab =6.00; phimax =3.36; gamma =1.60; betamin =0.50; db =3.22; c =0.37;
# 2060
# alpha =1.23; Ks =0.10; theta =1.71; Ln =0.12; kappab =0.01; phimax =0.30; gamma =1.18; betamin =0.99; db =5.98; c =0.12;
# 2091
# alpha =0.88; Ks =0.19; theta =3.40; Ln =0.62; kappab =0.03; phimax =1.57; gamma =3.46; betamin =0.01; db =3.22; c =0.27;
# 2175
# alpha =0.79; Ks =0.17; theta =3.25; Ln =0.51; kappab =4.21; phimax =3.76; gamma =1.87; betamin =0.65; db =1.78; c =0.07;
# 2289
# alpha =0.84; Ks =0.19; theta =3.58; Ln =0.40; kappab =6.00; phimax =0.00; gamma =1.42; betamin =0.00; db =6.00; c =0.60;
# 2345
# alpha =0.69; Ks =0.20; theta =4.24; Ln =0.22; kappab =1.49; phimax =2.23; gamma =1.60; betamin =0.67; db =1.91; c =0.23;
# 2405
# alpha =0.64; Ks =0.20; theta =4.62; Ln =0.34; kappab =0.00; phimax =3.37; gamma =0.77; betamin =1.00; db =2.83; c =0.00;
# 2449
# alpha =0.95; Ks =0.13; theta =2.03; Ln =0.17; kappab =0.00; phimax =0.00; gamma =1.41; betamin =0.68; db =1.58; c =0.02;
# 2514
# alpha =0.75; Ks =0.22; theta =4.67; Ln =0.56; kappab =5.95; phimax =6.00; gamma =1.05; betamin =0.99; db =5.91; c =0.77;
# 2590
# alpha =1.00; Ks =0.14; theta =2.37; Ln =0.30; kappab =2.32; phimax =5.20; gamma =1.08; betamin =0.00; db =6.00; c =1.00;
# 2631
# alpha =0.82; Ks =0.19; theta =3.34; Ln =0.49; kappab =4.39; phimax =1.79; gamma =1.36; betamin =0.23; db =2.97; c =0.57;
# 2699
# alpha =0.81; Ks =0.18; theta =3.51; Ln =0.38; kappab =1.19; phimax =1.09; gamma =3.54; betamin =0.00; db =0.59; c =0.25;
# 2779
# alpha =0.88; Ks =0.16; theta =2.88; Ln =0.29; kappab =2.85; phimax =1.03; gamma =2.61; betamin =0.00; db =3.74; c =0.34;
# 3148
# alpha =0.85; Ks =0.20; theta =3.68; Ln =0.73; kappab =0.27; phimax =4.62; gamma =0.92; betamin =0.00; db =6.00; c =1.00;
# 3415
# alpha =0.81; Ks =0.16; theta =3.16; Ln =0.33; kappab =0.00; phimax =2.71; gamma =0.96; betamin =1.00; db =3.75; c =0.16;
# 3786
# alpha =0.96; Ks =0.14; theta =2.33; Ln =0.36; kappab =0.00; phimax =0.00; gamma =1.83; betamin =0.00; db =6.00; c =0.54;
# 4124
# alpha =0.82; Ks =0.17; theta =2.88; Ln =0.40; kappab =6.00; phimax =1.27; gamma =1.77; betamin =0.40; db =5.73; c =0.15;
# 4318
# alpha =0.74; Ks =0.20; theta =3.74; Ln =0.27; kappab =6.00; phimax =2.70; gamma =0.92; betamin =0.88; db =5.24; c =0.04;
# 4665
# alpha =0.75; Ks =0.19; theta =3.43; Ln =0.48; kappab =0.32; phimax =0.03; gamma =4.01; betamin =0.00; db =5.39; c =0.20;
# 5107
# alpha =0.80; Ks =0.18; theta =3.31; Ln =0.54; kappab =6.00; phimax =0.98; gamma =2.13; betamin =0.00; db =6.00; c =0.45;
# 5509
# alpha =0.76; Ks =0.20; theta =3.65; Ln =0.33; kappab =6.00; phimax =2.04; gamma =2.33; betamin =0.00; db =2.83; c =0.36;
# 5826
# alpha =0.78; Ks =0.19; theta =3.40; Ln =0.26; kappab =5.95; phimax =5.81; gamma =1.92; betamin =0.00; db =3.00; c =0.48;
# 6039
# alpha =0.85; Ks =0.16; theta =2.53; Ln =0.45; kappab =1.46; phimax =4.39; gamma =3.85; betamin =0.02; db =4.41; c =0.28;
# 1026002900
# alpha =0.82; Ks =0.12; theta =3.69; Ln =0.22; kappab =0.00; phimax =2.99; gamma =5.38; betamin =0.00; db =0.01; c =0.18;
# MD0040
# alpha =1.00; Ks =0.11; theta =2.11; Ln =0.35; kappab =5.99; phimax =6.00; gamma =1.58; betamin =0.47; db =6.00; c =0.53;
# DICON003
# alpha =0.82; Ks =0.17; theta =3.08; Ln =0.25; kappab =6.00; phimax =4.16; gamma =1.36; betamin =0.00; db =2.24; c =0.66;
# DICON026
# alpha =2.23; Ks =0.04; theta =1.47; Ln =0.22; kappab =6.00; phimax =6.00; gamma =1.97; betamin =1.00; db =6.00; c =1.00;
# DICON044
# alpha =0.85; Ks =0.20; theta =3.37; Ln =0.39; kappab =6.00; phimax =0.00; gamma =2.81; betamin =0.00; db =6.00; c =0.30;
# DICON060
# alpha =0.87; Ks =0.18; theta =3.19; Ln =0.25; kappab =3.11; phimax =6.00; gamma =6.00; betamin =0.00; db =4.20; c =0.17;
# DICON098
# alpha =1.23; Ks =0.14; theta =2.57; Ln =0.35; kappab =0.17; phimax =0.94; gamma =2.31; betamin =0.05; db =1.75; c =0.50;
# DICON126
# alpha =1.22; Ks =0.07; theta =1.46; Ln =0.41; kappab =0.00; phimax =0.00; gamma =2.04; betamin =0.00; db =3.16; c =0.58;
# DICON174
# alpha =0.93; Ks =0.18; theta =2.84; Ln =0.43; kappab =0.29; phimax =1.04; gamma =1.90; betamin =0.01; db =1.21; c =0.36;
# DICON210
# alpha =1.04; Ks =0.14; theta =2.30; Ln =0.48; kappab =0.00; phimax =0.00; gamma =1.82; betamin =0.00; db =5.35; c =0.58;
# 2004
# alpha =0.87; Ks =0.11; theta =1.83; Ln =0.19; kappab =0.07; phimax =1.44; gamma =1.10; betamin =0.80; db =0.00; c =0.07;
# 2005
# alpha =1.03; Ks =0.15; theta =2.21; Ln =0.16; kappab =0.00; phimax =4.73; gamma =1.20; betamin =0.91; db =5.61; c =0.13;
# 2007
# alpha =0.88; Ks =0.17; theta =2.63; Ln =0.31; kappab =5.96; phimax =1.87; gamma =1.56; betamin =0.00; db =6.00; c =0.64;
# 2009
# alpha =0.84; Ks =0.19; theta =3.64; Ln =0.28; kappab =5.58; phimax =0.00; gamma =1.73; betamin =0.00; db =5.89; c =0.51;
# 2039
# alpha =0.84; Ks =0.19; theta =3.38; Ln =0.09; kappab =0.00; phimax =0.99; gamma =1.37; betamin =0.54; db =0.00; c =0.33;
# 2045
# alpha =0.85; Ks =0.20; theta =3.85; Ln =0.38; kappab =6.00; phimax =6.00; gamma =5.30; betamin =0.00; db =0.00; c =0.49;
# 2050
# alpha =0.78; Ks =0.18; theta =3.35; Ln =0.34; kappab =1.92; phimax =5.71; gamma =3.17; betamin =0.00; db =3.65; c =0.31;
# 2055
# alpha =0.91; Ks =0.19; theta =3.03; Ln =0.16; kappab =2.07; phimax =6.00; gamma =1.52; betamin =0.00; db =2.01; c =0.62;
# 2060
# alpha =1.23; Ks =0.10; theta =1.71; Ln =0.08; kappab =0.03; phimax =0.00; gamma =1.59; betamin =0.72; db =5.31; c =0.00;
# 2091
# alpha =0.88; Ks =0.19; theta =3.40; Ln =0.44; kappab =5.30; phimax =0.30; gamma =1.43; betamin =0.00; db =6.00; c =0.62;
# 2175
# alpha =0.79; Ks =0.17; theta =3.25; Ln =0.53; kappab =6.00; phimax =2.68; gamma =2.36; betamin =0.44; db =3.64; c =0.06;
# 2289
# alpha =0.84; Ks =0.19; theta =3.58; Ln =0.46; kappab =5.13; phimax =3.51; gamma =1.53; betamin =0.74; db =2.83; c =0.06;
# 2345
# alpha =0.69; Ks =0.20; theta =4.24; Ln =0.27; kappab =0.00; phimax =3.87; gamma =1.05; betamin =0.75; db =6.00; c =0.04;
# 2405
# alpha =0.64; Ks =0.20; theta =4.62; Ln =0.23; kappab =0.00; phimax =2.89; gamma =0.72; betamin =0.98; db =0.33; c =0.00;
# 2449
# alpha =0.95; Ks =0.13; theta =2.03; Ln =0.20; kappab =0.03; phimax =0.00; gamma =1.04; betamin =0.93; db =1.11; c =0.14;
# 2514
# alpha =0.75; Ks =0.22; theta =4.67; Ln =0.32; kappab =6.00; phimax =3.11; gamma =1.75; betamin =0.49; db =3.25; c =0.06;
# 2590
# alpha =1.00; Ks =0.14; theta =2.37; Ln =0.42; kappab =2.08; phimax =2.28; gamma =2.43; betamin =0.00; db =1.75; c =0.48;
# 2631
# alpha =0.82; Ks =0.19; theta =3.34; Ln =0.28; kappab =0.01; phimax =0.04; gamma =2.04; betamin =0.00; db =3.24; c =0.41;
# 2699
# alpha =0.81; Ks =0.18; theta =3.51; Ln =0.48; kappab =2.24; phimax =4.47; gamma =3.05; betamin =0.19; db =3.18; c =0.21;
# 2779
# alpha =0.88; Ks =0.16; theta =2.88; Ln =0.20; kappab =3.97; phimax =0.00; gamma =2.51; betamin =0.00; db =6.00; c =0.34;
# 3148
# alpha =0.85; Ks =0.20; theta =3.68; Ln =0.80; kappab =0.00; phimax =1.72; gamma =1.78; betamin =0.00; db =5.98; c =0.55;
# 3415
# alpha =0.81; Ks =0.16; theta =3.16; Ln =0.36; kappab =0.41; phimax =2.71; gamma =1.72; betamin =0.66; db =0.27; c =0.31;
# 3786
# alpha =0.96; Ks =0.14; theta =2.33; Ln =0.64; kappab =1.12; phimax =0.08; gamma =3.25; betamin =0.00; db =5.02; c =0.35;
# 4124
# alpha =0.82; Ks =0.17; theta =2.88; Ln =0.37; kappab =0.21; phimax =2.26; gamma =2.64; betamin =0.00; db =5.96; c =0.33;
# 4318
# alpha =0.74; Ks =0.20; theta =3.74; Ln =0.59; kappab =2.52; phimax =2.76; gamma =2.74; betamin =0.00; db =6.00; c =0.34;
# 4665
# alpha =0.75; Ks =0.19; theta =3.43; Ln =0.23; kappab =0.00; phimax =2.16; gamma =0.74; betamin =0.00; db =6.00; c =1.00;
# 5107
# alpha =0.80; Ks =0.18; theta =3.31; Ln =0.32; kappab =0.00; phimax =4.44; gamma =1.15; betamin =0.28; db =2.16; c =0.67;
# 5509
# alpha =0.76; Ks =0.20; theta =3.65; Ln =0.50; kappab =6.00; phimax =3.24; gamma =1.98; betamin =0.47; db =3.74; c =0.13;
# 5826
# alpha =0.78; Ks =0.19; theta =3.40; Ln =0.18; kappab =1.61; phimax =5.59; gamma =5.42; betamin =0.00; db =2.27; c =0.17;
# 6039
# alpha =0.85; Ks =0.16; theta =2.53; Ln =0.39; kappab =5.97; phimax =0.01; gamma =1.86; betamin =0.03; db =5.99; c =0.52;
# 1026002900
# alpha =0.82; Ks =0.12; theta =3.69; Ln =0.21; kappab =6.00; phimax =0.06; gamma =0.95; betamin =0.00; db =6.00; c =1.00;
# MD0040
# alpha =1.00; Ks =0.11; theta =2.11; Ln =0.27; kappab =6.00; phimax =3.17; gamma =4.33; betamin =0.00; db =6.00; c =0.25;
# DICON003
# alpha =0.82; Ks =0.17; theta =3.08; Ln =0.40; kappab =6.00; phimax =6.00; gamma =1.95; betamin =0.00; db =3.99; c =0.53;
# DICON026
# alpha =2.23; Ks =0.04; theta =1.47; Ln =0.59; kappab =5.85; phimax =6.00; gamma =2.48; betamin =0.00; db =1.85; c =1.00;
# DICON044
# alpha =0.85; Ks =0.20; theta =3.37; Ln =0.24; kappab =6.00; phimax =0.41; gamma =1.59; betamin =0.46; db =4.86; c =0.06;
# DICON060
# alpha =0.87; Ks =0.18; theta =3.19; Ln =0.19; kappab =6.00; phimax =6.00; gamma =0.98; betamin =0.00; db =2.89; c =1.00;
# DICON098
# alpha =1.23; Ks =0.14; theta =2.57; Ln =0.64; kappab =5.78; phimax =4.12; gamma =1.40; betamin =0.30; db =6.00; c =0.93;
# DICON126
# alpha =1.22; Ks =0.07; theta =1.46; Ln =0.44; kappab =2.69; phimax =0.00; gamma =4.58; betamin =0.00; db =5.28; c =0.26;
# DICON174
# alpha =0.93; Ks =0.18; theta =2.84; Ln =0.47; kappab =2.69; phimax =0.22; gamma =1.76; betamin =0.01; db =5.57; c =0.39;
# DICON210
# alpha =1.04; Ks =0.14; theta =2.30; Ln =0.59; kappab =1.28; phimax =0.00; gamma =5.37; betamin =0.00; db =6.00; c =0.20;

# %% [markdown]
# The following code checks the quality of estimated parameters
# 1. Load the estimated parameters
# 2. For each parameter set, conduct simulations with the defined timespan for the three conditions: (0, 0), (10, 0), (3, 10)
# 3. In each simulation, n0 is set by using the first value of the corresponding experimental data
# 4. For each parameter set, generate a 3-panel plot. Each panel shows the overlay of simulated data and experimental data for one of the 3 conditions.
# 5. When doing the optimization, the experimental time points are not considered. Instead, a reasonable time span is used to simulate time courses. It is close but not identical to experimental time span. This can be corrected later by re-scaling the time axis of the simulation.
